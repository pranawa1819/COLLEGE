# %%
import pandas as pd

# %%
l = range(5,10)
series = pd.Series(l)
series
# Out:
# 0    5
# 1    6
# 2    7
# 3    8
# 4    9
# dtype: int64

# %%
d={
    "math":[1,2,3,4,5,6],
    "science":[10,11,12,13,14,15]
}
df=pd.DataFrame(d)
df
# Out:
#    math  science
# 0     1       10
# 1     2       11
# 2     3       12
# 3     4       13
# 4     5       14
# 5     6       15

# %%
df.tail(3)
# Out:
#    math  science
# 3     4       13
# 4     5       14
# 5     6       15

# %%
filepath = "C:\\Users\\LENOVO\\Desktop\\python file\\pranawa\\data\\organizations-10000.csv" #control d will select all the similar data

# %%
import os 
os.path.exists(filepath)
# Out:
# True

# %%
df=pd.read_csv(filepath)  #pd.read_csv(filepath,delimiter='\t')
df
# Out:
#       Index  Organization Id                         Name  \
# 0         1  522816eF8fdBE6d                 Mckinney PLC
# 1         2  70C7FBD7e6Aa3Ea               Cunningham LLC
# 2         3  428B397eA2d7290                   Ruiz-Walls
# 3         4  9D234Ae8Cc51C1c  Parrish, Osborne and Clarke
# 4         5  6CDCcdE3D0b7b44       Diaz, Robles and Haley
# ...     ...              ...                          ...
# 9995   9996  2EE82AD1Cd045cd           Neal, Day and Wang
# 9996   9997  06f1568A2CaF04a    Barrett, Rojas and Adkins
# 9997   9998  B4B92A44e0331Bc               Franklin-Ayala
# 9998   9999  01D2539e270CEbd                  Wolfe-Mckee
# 9999  10000  0D3b7DcFA21d92d                     Beck LLC
#
#                             Website  \
# 0                  http://soto.com/
# 1         http://harding-duffy.com/
# 2            http://www.atkins.biz/
# 3              http://salazar.info/
# 4     https://www.brooks-scott.net/
# ...                             ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Index                10000 non-null  int64
#  1   Organization Id      10000 non-null  object
#  2   Name                 10000 non-null  object
#  3   Website              10000 non-null  object
#  4   Country              9999 non-null   object
#  5   Description          10000 non-null  object
#  6   Founded              10000 non-null  int64
#  7   Industry             10000 non-null  object
#  8   Number of employees  10000 non-null  int64
# dtypes: int64(3), object(6)
# memory usage: 703.3+ KB

# %%
df.describe() # numeric data ko static value nikalcha
# Out:
#              Index       Founded  Number of employees
# count  10000.00000  10000.000000         10000.000000
# mean    5000.50000   1995.776700          4961.321000
# std     2886.89568     14.991608          2911.862096
# min        1.00000   1970.000000             1.000000
# 25%     2500.75000   1983.000000          2446.750000
# 50%     5000.50000   1996.000000          4894.000000
# 75%     7500.25000   2009.000000          7530.000000
# max    10000.00000   2022.000000          9999.000000

# %%
new_df=df.drop('Index',axis=1, inplace=False)
new_df
# Out:
#       Organization Id                         Name  \
# 0     522816eF8fdBE6d                 Mckinney PLC
# 1     70C7FBD7e6Aa3Ea               Cunningham LLC
# 2     428B397eA2d7290                   Ruiz-Walls
# 3     9D234Ae8Cc51C1c  Parrish, Osborne and Clarke
# 4     6CDCcdE3D0b7b44       Diaz, Robles and Haley
# ...               ...                          ...
# 9995  2EE82AD1Cd045cd           Neal, Day and Wang
# 9996  06f1568A2CaF04a    Barrett, Rojas and Adkins
# 9997  B4B92A44e0331Bc               Franklin-Ayala
# 9998  01D2539e270CEbd                  Wolfe-Mckee
# 9999  0D3b7DcFA21d92d                     Beck LLC
#
#                             Website  \
# 0                  http://soto.com/
# 1         http://harding-duffy.com/
# 2            http://www.atkins.biz/
# 3              http://salazar.info/
# 4     https://www.brooks-scott.net/
# ...                             ...
# 9995            https://carson.net/
# 9996     https://douglas-garza.com/
# ...

# %%
new_df=df.drop('Index',axis=1, inplace=True)
print(new_df)
# Out:
# None

# %%
df.head(2)
# Out:
#    Organization Id            Name                    Website  Country  \
# 0  522816eF8fdBE6d    Mckinney PLC           http://soto.com/      NaN
# 1  70C7FBD7e6Aa3Ea  Cunningham LLC  http://harding-duffy.com/  Namibia
#
#                             Description  Founded Industry  Number of employees
# 0       Synergized global system engine     1988    Dairy                 3930
# 1  Team-oriented fault-tolerant adapter     2018  Library                 7871

# %%
df.columns
# Out:
# Index(['Organization Id', 'Name', 'Website', 'Country', 'Description',
#        'Founded', 'Industry', 'Number of employees'],
#       dtype='object')

# %%
df.drop(
    ['Organization Id', 'Name', 'Website', 'Description'],
    axis=1, 
    inplace=True)

df.head(3)
# Out:
#    Country  Founded                Industry  Number of employees
# 0      NaN     1988                   Dairy                 3930
# 1  Namibia     2018                 Library                 7871
# 2     Iran     2003  Hospital / Health Care                 3095

# %%
df.isna()
# Out:
#       Country  Founded  Industry  Number of employees
# 0        True    False     False                False
# 1       False    False     False                False
# 2       False    False     False                False
# 3       False    False     False                False
# 4       False    False     False                False
# ...       ...      ...       ...                  ...
# 9995    False    False     False                False
# 9996    False    False     False                False
# 9997    False    False     False                False
# 9998    False    False     False                False
# 9999    False    False     False                False
#
# [10000 rows x 4 columns]

# %%
True+False+True
# Out:
# 2

# %%
df.isna().sum()
# Out:
# Country                1
# Founded                0
# Industry               0
# Number of employees    0
# dtype: int64

# %%
df.dropna(axis=1, inplace=True)      # axis = 0 ley row hataucha nan bhakoo anii axis=1 ley chaii column laii remove garchaa

# %%
df.head(2)
# Out:
#    Founded Industry  Number of employees
# 0     1988    Dairy                 3930
# 1     2018  Library                 7871

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated(['Founded','Industry'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995     True
# 9996     True
# 9997     True
# 9998     True
# 9999     True
# Length: 10000, dtype: bool

# %%
df.duplicated(['Founded','Industry']).sum()
# Out:
# np.int64(4356)

# %%
df.drop_duplicates(['Founded','Industry'])
# Out:
#       Founded                    Industry  Number of employees
# 0        1988                       Dairy                 3930
# 1        2018                     Library                 7871
# 2        2003      Hospital / Health Care                 3095
# 3        1989                Supermarkets                 5422
# 4        2013              Nanotechnology                 3135
# ...       ...                         ...                  ...
# 9967     2011              Semiconductors                 9227
# 9974     2001                    Fine Art                 5622
# 9977     1978                 Restaurants                 6648
# 9982     1984  Package / Freight Delivery                 4264
# 9985     2016       International Affairs                 6409
#
# [5644 rows x 3 columns]

# %%
df.drop_duplicates(['Founded','Industry']).reset_index(drop=True)
# Out:
#       Founded                    Industry  Number of employees
# 0        1988                       Dairy                 3930
# 1        2018                     Library                 7871
# 2        2003      Hospital / Health Care                 3095
# 3        1989                Supermarkets                 5422
# 4        2013              Nanotechnology                 3135
# ...       ...                         ...                  ...
# 5639     2011              Semiconductors                 9227
# 5640     2001                    Fine Art                 5622
# 5641     1978                 Restaurants                 6648
# 5642     1984  Package / Freight Delivery                 4264
# 5643     2016       International Affairs                 6409
#
# [5644 rows x 3 columns]

# %%
type(df['Founded'])
# Out:
# pandas.core.series.Series

# %%
type(df[['Founded']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Founded']]
# Out:
#       Founded
# 0        1988
# 1        2018
# 2        2003
# 3        1989
# 4        2013
# ...       ...
# 9995     2013
# 9996     2018
# 9997     1983
# 9998     1975
# 9999     2007
#
# [10000 rows x 1 columns]

# %%
df.rename(
    columns={'Number of employees':'N_Employees'}
)
# Out:
#       Founded                Industry  N_Employees
# 0        1988                   Dairy         3930
# 1        2018                 Library         7871
# 2        2003  Hospital / Health Care         3095
# 3        1989            Supermarkets         5422
# 4        2013          Nanotechnology         3135
# ...       ...                     ...          ...
# 9995     2013         Import / Export         6123
# 9996     2018    Human Resources / HR         9043
# 9997     1983      Financial Services         8951
# 9998     1975  Environmental Services         2505
# 9999     2007                Wireless         4552
#
# [10000 rows x 3 columns]

# %%
df['Number of employees'].mean()
# Out:
# np.float64(4961.321)

# %%
df['Number of employees'].median()
# Out:
# np.float64(4894.0)
